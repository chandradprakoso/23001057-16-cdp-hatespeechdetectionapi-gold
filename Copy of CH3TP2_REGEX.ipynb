# %%
import re

# %% [markdown]
# # How to split a string separated by a regex?

# %%
text = """101 COM   Computers
205 MAT   Mathematics
189 ENG   English""" 

text = re.split('\s+', text)
print(text)
# Out:
# ['101', 'COM', 'Computers', '205', 'MAT', 'Mathematics', '189', 'ENG', 'English']

# %%
text
# Out:
# ['101',
#  'COM',
#  'Computers',
#  '205',
#  'MAT',
#  'Mathematics',
#  '189',
#  'ENG',
#  'English']

# %%
print(text)
# Out:
# ['101', 'COM', 'Computers', '205', 'MAT', 'Mathematics', '189', 'ENG', 'English']

# %% [markdown]
# # Finding pattern matches using findall, search and match

# %% [markdown]
# **re.findall()**

# %%
text = """101 COM    Computers
205 MAT   Mathematics
189 ENG   English""" 

regex_num = re.compile('\d+')
regex_num.findall(text)
# Out:
# ['101', '205', '189']

# %%
regex_num1 = re.findall('[0-9]+',text)
regex_num1
# Out:
# ['101', '205', '189']

# %% [markdown]
# **re.search()**

# %%
# define the text
text2 = """205 COM    Computers MAT   Mathematics 189"""

# compile the regex and search the pattern
regex_num = re.compile('\d+')
s = regex_num.search(text2)
# print(s)

print('Starting Position: ', s.start())
print('Ending Position: ', s.end())
# Out:
# Starting Position:  0
# Ending Position:  3

# %% [markdown]
# # How to substitute one text with another using regex?

# %%
text = """101   COM \t  Computers
205   MAT \t  Mathematics
189   ENG  \t  English"""
print(text)
print("=========================")
text = re.sub('\t', '_', text)
print(text)
# Out:
# 101   COM 	  Computers
# 205   MAT 	  Mathematics
# 189   ENG  	  English
# =========================
# 101   COM _  Computers
# 205   MAT _  Mathematics
# 189   ENG  _  English

# %%
text = "moch ari n"
print(text)
print('=========================')

print(re.sub('\s+', '__', text))
# Out:
# moch ari n
# =========================
# moch__ari__n

# %% [markdown]
# # Regex groups

# %%
text = """101   COM   Computers
205   MAT   Mathematics
189   ENG    English"""

# %% [markdown]
# **Extract all course numbers**

# %%
text = """101   COM   Computers
205   MAT   Mathematics
189   ENG    English"""  

print(re.findall('[0-9]+', text))
# Out:
# ['101', '205', '189']

# %% [markdown]
# **Extract all course codes**

# %%
text = """101   COM   Computers
205   MAT   Mathematics
189   ENG    English"""

print(re.findall('[A-Z]{3}', text))
# Out:
# ['COM', 'MAT', 'ENG']

# %% [markdown]
# **Extract all course names**

# %%
text = """101   COM   Computers
205   MAT   Mathematics
189   ENG    English"""

print(re.findall('[A-Za-z]{4,}', text))
# Out:
# ['Computers', 'Mathematics', 'English']

# %% [markdown]
# # Regex for text cleansing

# %%
text = """
To be fair, the app works to an extent. I can register and get my payment code etc, works "well" until the status takes days to update.

You see, problems like this can easily be solved by proper tech. That is NOT the problem.

The problem is everything but tech?.

https://lalalaa.com
"""

text
# Out:
# '\nTo be fair, the app works to an extent. I can register and get my payment code etc, works "well" until the status takes days to update.\n\nYou see, problems like this can easily be solved by proper tech. That is NOT the problem.\n\nThe problem is everything but tech?.\n\nhttps://lalalaa.com\n'

# %% [markdown]
# **Remove URL**

# %%
text = """
To be fair, the app works to an extent. I can register and get my payment code etc, works "well" until the status takes days to update.

You see, problems like this can easily be solved by proper tech. That is NOT the problem.

The problem is everything but tech?.

https://lalalaa.com
"""
text = re.sub('http\S+', '', text)
text
# Out:
# '\nTo be fair, the app works to an extent. I can register and get my payment code etc, works "well" until the status takes days to update.\n\nYou see, problems like this can easily be solved by proper tech. That is NOT the problem.\n\nThe problem is everything but tech?.\n\n\n'

# %% [markdown]
# **Menghapus emoticon dan tanda baca**

# %%
text = """
To be fair 1000, the app works to an extent. I can register and get my payment code etc, works "well" until the status takes days to update.

You see, problems like this can easily be solved by proper tech. That is NOT the problem.

The problem is everything but tech?.

https://lalalaa.com
"""
text = re.sub(r'[^a-zA-Z0-9]', ' ', text)
text
# Out:
# ' To be fair 1000  the app works to an extent  I can register and get my payment code etc  works  well  until the status takes days to update   You see  problems like this can easily be solved by proper tech  That is NOT the problem   The problem is everything but tech    https   lalalaa com '

# %%
text = text.strip()
text
# Out:
# 'To be fair 1000  the app works to an extent  I can register and get my payment code etc  works  well  until the status takes days to update   You see  problems like this can easily be solved by proper tech  That is NOT the problem   The problem is everything but tech    https   lalalaa com'

# %%
import pandas as pd

# %%
data = pd.read_csv('Latihan Cleansing.csv')
data.head()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /Users/chandra/Documents/BINAR_DSC_ENV/.venv/Copy of CH3TP2_REGEX.ipynb Cell 31 line 1
# ----> <a href='vscode-notebook-cell:/Users/chandra/Documents/BINAR_DSC_ENV/.venv/Copy%20of%20CH3TP2_REGEX.ipynb#X42sZmlsZQ%3D%3D?line=0'>1</a> data = pd.read_csv('Latihan Cleansing.csv')
#       <a href='vscode-notebook-cell:/Users/chandra/Documents/BINAR_DSC_ENV/.venv/Copy%20of%20CH3TP2_REGEX.ipynb#X42sZmlsZQ%3D%3D?line=1'>2</a> data.head()
#
# File ~/Documents/BINAR_DSC_ENV/.venv/lib/python3.8/site-packages/pandas/io/parsers/readers.py:912, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#     899 kwds_defaults = _refine_defaults_read(
#     900     dialect,
#     901     delimiter,
#    (...)
#     908     dtype_backend=dtype_backend,
#     909 )
#     910 kwds.update(kwds_defaults)
# --> 912 return _read(filepath_or_buffer, kwds)
#
# File ~/Documents/BINAR_DSC_ENV/.venv/lib/python3.8/site-packages/pandas/io/parsers/readers.py:577, in _read(filepath_or_buffer, kwds)
#     574 _validate_names(kwds.get("names", None))
#     576 # Create the parser.
# --> 577 parser = TextFileReader(filepath_or_buffer, **kwds)
#     579 if chunksize or iterator:
#     580     return parser
#
# File ~/Documents/BINAR_DSC_ENV/.venv/lib/python3.8/site-packages/pandas/io/parsers/readers.py:1407, in TextFileReader.__init__(self, f, engine, **kwds)
#    1404     self.options["has_index_names"] = kwds["has_index_names"]
#    1406 self.handles: IOHandles | None = None
# -> 1407 self._engine = self._make_engine(f, self.engine)
#
# File ~/Documents/BINAR_DSC_ENV/.venv/lib/python3.8/site-packages/pandas/io/parsers/readers.py:1661, in TextFileReader._make_engine(self, f, engine)
#    1659     if "b" not in mode:
#    1660         mode += "b"
# -> 1661 self.handles = get_handle(
#    1662     f,
#    1663     mode,
#    1664     encoding=self.options.get("encoding", None),
#    1665     compression=self.options.get("compression", None),
#    1666     memory_map=self.options.get("memory_map", False),
#    1667     is_text=is_text,
#    1668     errors=self.options.get("encoding_errors", "strict"),
#    1669     storage_options=self.options.get("storage_options", None),
#    1670 )
#    1671 assert self.handles is not None
#    1672 f = self.handles.handle
#
# File ~/Documents/BINAR_DSC_ENV/.venv/lib/python3.8/site-packages/pandas/io/common.py:859, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     854 elif isinstance(handle, str):
#     855     # Check whether the filename is to be opened in binary mode.
#     856     # Binary mode does not support 'encoding' and 'newline'.
#     857     if ioargs.encoding and "b" not in ioargs.mode:
#     858         # Encoding
# --> 859         handle = open(
#     860             handle,
#     861             ioargs.mode,
#     862             encoding=ioargs.encoding,
#     863             errors=errors,
#     864             newline="",
#     865         )
#     866     else:
#     867         # Binary mode
#     868         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'Latihan Cleansing.csv'

# %%
# Selanjutnya kita akan memulai cleansing (pembersihan) pada kolom "text" dari DataFrame.
# Untuk melakukan cleansing, terlebih dahulu kita perlu mendefinisikan sebuah fungsi.
# Fungsi ini diberi nama "cleansing"

# Terlebih dahulu kita import library bernama "RegEx".
# "RegEx" merupakan library yang digunakan untuk memanipulasi data text berdasarkan pola text-nya
# Kita panggil library "RegEx" sebagai berikut:
import re

# Selanjutnya berbagai jenis cleansing yang digunakan sebagai berikut
def cleansing(sent):
    # Mengubah kata menjadi huruf kecil semua dengan menggunakan fungsi lower()
    string = str(sent).lower()
    # Menghapus emoticon dan tanda baca menggunakan "RegEx" dengan script di bawah
    string = re.sub(r'[^a-zA-Z0-9]', ' ', string)
    return string

# %%
data.columns
# Out:
# Index(['Id', 'Sentiment', 'Acara TV', 'Jumlah Retweet', 'Text Tweet',
#        'text_clean'],
#       dtype='object')

# %%
# Setelah selesai mendefinisikan fungsi "cleansing", selanjutnya kita aplikasikan ke dalam kolom text pada DataFrame
# Caranya menjalankan script di bawah
data['text_clean'] = data['Text Tweet'].apply(cleansing)

# %%
data.head()
# Out:
#    Id Sentiment           Acara TV  Jumlah Retweet  \
# 0   1  positive  HitamPutihTransTV              12
# 1   2  positive  HitamPutihTransTV               6
# 2   3  positive  HitamPutihTransTV               9
# 3   4  positive  HitamPutihTransTV               2
# 4   5  positive  HitamPutihTransTV               1
#
#                                           Text Tweet  \
# 0  Undang @N_ShaniJKT48 ke hitamputih, pemenang S...
# 1  Selamat berbuka puasa Semoga amal ibadah hari ...
# 2  Ada nih di trans7 hitam putih, dia dpt penghar...
# 3        selamat ya mas @adietaufan masuk hitamputih
# 4                  Asiknya nonton Hitam Putih Trans7
#
#                                           text_clean
# 0  undang  n shanijkt48 ke hitamputih  pemenang s...
# 1  selamat berbuka puasa semoga amal ibadah hari ...
# 2  ada nih di trans7 hitam putih  dia dpt penghar...
# 3        selamat ya mas  adietaufan masuk hitamputih
# 4                  asiknya nonton hitam putih trans7
